# %%
# Import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
airlines_kaggle_file = "../Data Extracted/airlines.csv"
airlines_df = pd.read_csv(airlines_kaggle_file) 
airlines_df.head()
# Out:
#    Airline ID                                          Name Alias IATA ICAO  \
# 0          -1                                       Unknown    \N    -  NaN
# 1           1                                Private flight    \N    -  NaN
# 2           2                                   135 Airways    \N  NaN  GNL
# 3           3                                 1Time Airline    \N   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN  WYT
#
#   Callsign         Country Active
# 0       \N              \N      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %%
# Look for missing values/ if any
airlines_df.count()
# Out:
# Airline ID    6162
# Name          6162
# Alias         5656
# IATA          1535
# ICAO          6075
# Callsign      5354
# Country       6147
# Active        6162
# dtype: int64

# %% [markdown]
# ### Rename "Name" column header to "Airline

# %%
clean_df = airlines_df = airlines_df.rename(columns={'Name':'Airline'})
clean_df
# Out:
#       Airline ID                                       Airline  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# ...

# %% [markdown]
# ### Count Duplicates in the "Airline" column

# %%
name_unique_count = airlines_df['Airline'].nunique()
name_unique_count
# Out:
# 6073

# %% [markdown]
# ### Drop Duplicates in "Airline" Column

# %%
clean_df = airlines_df.drop_duplicates(subset=['Airline'])
clean_df
# Out:
#       Airline ID                                       Airline  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# ...

# %%
# Drop Airline ID "-1" row
clean_df = clean_df.drop([0,0])
clean_df = clean_df.reset_index()

# %%
clean_df
# Out:
#       level_0  index  Airline ID  \
# 0           1      2           2
# 1           2      3           3
# 2           3      4           4
# 3           4      5           5
# 4           5      6           6
# ...       ...    ...         ...
# 6066     6067   6157       21248
# 6067     6068   6158       21251
# 6068     6069   6159       21268
# 6069     6070   6160       21270
# 6070     6071   6161       21317
#
#                                            Airline              Alias IATA  \
# 0                                      135 Airways                 \N  NaN
# 1                                    1Time Airline                 \N   1T
# 2     2 Sqn No 1 Elementary Flying Training School                 \N  NaN
# 3                                  213 Flight Unit                 \N  NaN
# 4                    223 Flight Unit State Airline                 \N  NaN
# ...                                            ...                ...  ...
# ...

# %%
clean_df = clean_df.drop(columns=['level_0','index'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-013ab1913b73> in <module>
# ----> 1 clean_df = clean_df.drop(columns=['level_0','index'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
clean_df.to_csv("../Data Transformed/airlines_cleaned.csv", index = False)
