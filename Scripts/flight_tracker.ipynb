# %%
# import dependancies
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# extract data file
filepath = "../Data Extracted/airline_portcountry.csv"
df = pd.read_csv(filepath)
df
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 0      Jan-85          Air Caledonie  New Caledonia          725.0
# 1      Jan-85              Air China          China         1311.0
# 2      Jan-85              Air India          India         1423.0
# 3      Jan-85              Air India      Singapore          501.0
# 4      Jan-85              Air Nauru          Nauru          161.0
# ...       ...                    ...            ...            ...
# 43851  Nov-21  United Parcel Service          Korea            0.0
# 43852  Nov-21  United Parcel Service      Singapore            0.0
# 43853  Nov-21  United Parcel Service            USA            0.0
# 43854  Nov-21       Vietnam Airlines        Vietnam          360.0
# 43855  Nov-21        Xiamen Airlines          China          206.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0                    0.368             0.000           474.0
# 1                    9.158             0.000          1232.0
# 2                   44.823             0.000           970.0
# 3                   10.583             0.000           306.0
# 4                    0.212             0.000            96.0
# ...                    ...               ...             ...
# 43851                0.000             0.000             0.0
# 43852                0.000             0.000             0.0
# 43853             1622.587             0.000             0.0
# 43854              487.621             1.237           442.0
# 43855              131.500             2.900          1385.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Year  Month_num
# 0                     0.167              0.000  1985          1
# 1                     2.587              0.000  1985          1
# 2                     6.708              0.000  1985          1
# 3                   124.966              0.000  1985          1
# 4                    23.996              0.000  1985          1
# ...                     ...                ...   ...        ...
# 43851               614.750              0.000  2021         11
# 43852               263.367              0.000  2021         11
# 43853                 0.000              0.000  2021         11
# 43854               407.243              6.765  2021         11
# 43855               111.200              0.000  2021         11
#
# [43856 rows x 11 columns]

# %% [markdown]
# # Transform data

# %% [markdown]
# ### Create a table of porting country

# %%
port_country_db = df[["Port_Country"]].copy()

# %%
# remove duplicates in country_port
port_country_db.drop_duplicates(inplace=True)
port_country_db.sort_values("Port_Country", inplace=True)

# allocate Id number to each country
port_country_db["id"] = port_country_db['Port_Country'].astype('category').cat.codes

# rearrange columns
port_country_db = port_country_db[["id", "Port_Country"]]

# set new index column
port_country_db.set_index("id",drop = True)
# Out:
#       Port_Country
# id
# 0   American Samoa
# 1        Argentina
# 2          Austria
# 3          Bahrain
# 4          Belgium
# ..             ...
# 69         Vietnam
# 70   Wallis Island
# 71   Western Samoa
# 72      Yugoslavia
# 73        Zimbabwe
#
# [74 rows x 1 columns]

# %%
port_country_db.to_csv("../Data Transformed/Port_Country.csv", index = False)

# %% [markdown]
# ### Create a table of airline

# %%
df
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 0      Jan-85          Air Caledonie  New Caledonia          725.0
# 1      Jan-85              Air China          China         1311.0
# 2      Jan-85              Air India          India         1423.0
# 3      Jan-85              Air India      Singapore          501.0
# 4      Jan-85              Air Nauru          Nauru          161.0
# ...       ...                    ...            ...            ...
# 43851  Nov-21  United Parcel Service          Korea            0.0
# 43852  Nov-21  United Parcel Service      Singapore            0.0
# 43853  Nov-21  United Parcel Service            USA            0.0
# 43854  Nov-21       Vietnam Airlines        Vietnam          360.0
# 43855  Nov-21        Xiamen Airlines          China          206.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0                    0.368             0.000           474.0
# 1                    9.158             0.000          1232.0
# 2                   44.823             0.000           970.0
# 3                   10.583             0.000           306.0
# 4                    0.212             0.000            96.0
# ...                    ...               ...             ...
# 43851                0.000             0.000             0.0
# 43852                0.000             0.000             0.0
# 43853             1622.587             0.000             0.0
# 43854              487.621             1.237           442.0
# 43855              131.500             2.900          1385.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Year  Month_num
# 0                     0.167              0.000  1985          1
# 1                     2.587              0.000  1985          1
# 2                     6.708              0.000  1985          1
# 3                   124.966              0.000  1985          1
# 4                    23.996              0.000  1985          1
# ...                     ...                ...   ...        ...
# 43851               614.750              0.000  2021         11
# 43852               263.367              0.000  2021         11
# 43853                 0.000              0.000  2021         11
# 43854               407.243              6.765  2021         11
# 43855               111.200              0.000  2021         11
#
# [43856 rows x 11 columns]

# %%
filepath = "../Data Extracted/airlines.csv"
df2 = pd.read_csv(filepath)
df2
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# 1                    \N    -  NaN              NaN             NaN      Y
# 2                    \N  NaN  GNL          GENERAL   United States      N
# 3                    \N   1T  RNX          NEXTIME    South Africa      Y
# 4                    \N  NaN  WYT              NaN  United Kingdom      N
# ...                 ...  ...  ...              ...             ...    ...
# 6157                NaN  NaN  CBG            SPRAY           China      Y
# 6158                NaN  NaN  SSX           Shasta   United States      N
# 6159                NaN   JG   \N              NaN       Australia      Y
# 6160                NaN   2S   \N              NaN           India      Y
# 6161  Russian Commuter    7R  SJM  RussianConnecty          Russia      Y
#
# [6162 rows x 8 columns]

# %% [markdown]
# ### Data cleaning airline name columns - Testing

# %%
air_line_df = df[["Airline"]].drop_duplicates()
air_line_df.reset_index()
# Out:
#      index             Airline
# 0        0       Air Caledonie
# 1        1           Air China
# 2        2           Air India
# 3        4           Air Nauru
# 4        5     Air New Zealand
# ..     ...                 ...
# 134  39736    Donghai Airlines
# 135  41257      Thai AirAsia X
# 136  41502        Air Chathams
# 137  41750  Citilink Indonesia
# 138  42231         Kalitta Air
#
# [139 rows x 2 columns]

# %%
air_line_df2 = df2[["Name"]].drop_duplicates()

# %%
air_line_df2
# Out:
#                                               Name
# 0                                          Unknown
# 1                                   Private flight
# 2                                      135 Airways
# 3                                    1Time Airline
# 4     2 Sqn No 1 Elementary Flying Training School
# ...                                            ...
# 6157                                   GX Airlines
# 6158                        Lynx Aviation (L3/SSX)
# 6159                               Jetgo Australia
# 6160                                  Air Carnival
# 6161                                 Svyaz Rossiya
#
# [6073 rows x 1 columns]

# %%
# merge trial to see if the airline name matched
matching_df = air_line_df.merge(air_line_df2, left_on="Airline", right_on="Name",how = "left")

# %%
# matching result after merging
print(matching_df.loc[matching_df["Name"].isnull()])
print("----------")
print("Unmatched airlines:")
print(matching_df.loc[matching_df["Name"].isnull()].count())
# Out:
#                          Airline Name
# 0                  Air Caledonie  NaN
# 2                      Air India  NaN
# 3                      Air Nauru  NaN
# 10        Canadian Airlines Intl  NaN
# 11        Cathay Pacific Airways  NaN
# 13             Flying Tiger Line  NaN
# 17     Lufthansa German Airlines  NaN
# 19               Olympic Airways  NaN
# 20                  Pan American  NaN
# 23                Qantas Airways  NaN
# 28   Union de Transports Aeriens  NaN
# 29             Yugoslav Airlines  NaN
# 32    Cook Islands International  NaN
# 38   Federal Express Corporation  NaN
# 43              Pel-Air Aviation  NaN
# 48     Aeroflot Russian Intl A/l  NaN
# 49                   Sempati Air  NaN
# 51          Ansett International  NaN
# 52                       Eva Air  NaN
# 54            Ansett Air Freight  NaN
# 57       Connie Kalitta Services  NaN
# 61       Evergreen Intl Airlines  NaN
# 63     Kiwi Travel Intl Airlines  NaN
# 65                      EgyptAir  NaN
# 71             Martinair Holland  NaN
# 72     Freedom Air International  NaN
# 74                   MBA Pty Ltd  NaN
# 78                     Lan Chile  NaN
# 81        Cargolux Airlines Intl  NaN
# 87                  Virgin Samoa  NaN
# 88           Norfolk Jet Express  NaN
# 94                       Jetstar  NaN
# 101                     Silk Air  NaN
# 104        Tasman Cargo Airlines  NaN
# 105                  SkyAirWorld  NaN
# 106                        OzJet  NaN
# 107                  V Australia  NaN
# 112                Air Australia  NaN
# 113                 Jetstar Asia  NaN
# 114                 Fiji Airways  NaN
# 116                     Tigerair  NaN
# 119               Nauru Airlines  NaN
# 121             Cebu Pacific Air  NaN
# 122      Indonesia AirAsia Extra  NaN
# 126           Tigerair Australia  NaN
# 127               LATAM Airlines  NaN
# 128     Beijing Capital Airlines  NaN
# 130          Batik Air Indonesia  NaN
# 131               Scoot Tigerair  NaN
# 133                Samoa Airways  NaN
# 134             Donghai Airlines  NaN
# 135               Thai AirAsia X  NaN
# ----------
# Unmatched airlines:
# Airline    52
# Name        0
# dtype: int64

# %%
# Replace common words within airline name such as "Airlines", "Intl", "International"...for having better matching name:
# e.g : Canadian Airlines Intl vs Canadian Airlines;
# Air Caledonie International  vs Air Caledonie;
# Olympic Airways vs Olympic Airlines;
# Nauru Air Corporation vs Air Nauru.

# Use title() to avoid all upper case e.g: EVA Air vs Eva Air 
# remove multiple spaces within name after the above replacements

# Define function to clean column names
def clean(column):
    column = column.str.strip().str.replace("Airlines","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("Airways","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("A/l","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("Intl","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("International","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("Corporation","", case = False).str.strip().str.title()
    column = column.str.strip().str.replace("Air","", case = False).str.strip().str.title()
    column = column.replace('\s+', ' ', regex=True)
    return column

air_line_df["Airline"] = clean(air_line_df["Airline"])

air_line_df2["Name"] = clean(air_line_df2["Name"])

# %%
matching_df = air_line_df.merge(air_line_df2, left_on="Airline", right_on="Name",how = "left")

# %%
print(matching_df.loc[matching_df["Name"].isnull()])
print("----------")
print("Unmatched airlines:")
print(matching_df.loc[matching_df["Name"].isnull()].count())
# Out:
#                          Airline Name
# 18             Flying Tiger Line  NaN
# 23              Lufthansa German  NaN
# 34   Union De Transports Aeriens  NaN
# 35                      Yugoslav  NaN
# 39                  Cook Islands  NaN
# 50                 Pel- Aviation  NaN
# 56                       Sempati  NaN
# 58                        Ansett  NaN
# 61                Ansett Freight  NaN
# 65       Connie Kalitta Services  NaN
# 71                   Kiwi Travel  NaN
# 79                Martin Holland  NaN
# 84                   Mba Pty Ltd  NaN
# 88                     Lan Chile  NaN
# 99                  Virgin Samoa  NaN
# 100          Norfolk Jet Express  NaN
# 120                 Tasman Cargo  NaN
# 128                    Australia  NaN
# 138         Indonesia Asia Extra  NaN
# 144                        Latam  NaN
# 145              Beijing Capital  NaN
# 147              Batik Indonesia  NaN
# 148                  Scoot Tiger  NaN
# 150                        Samoa  NaN
# 151                      Donghai  NaN
# 152                  Thai Asia X  NaN
# ----------
# Unmatched airlines:
# Airline    26
# Name        0
# dtype: int64

# %% [markdown]
# ### Apply cleaning procedures to the actual data

# %% [markdown]
# ##### 1. Apply to airline_portcountry dataframe

# %%
# create a new column for matching purposes
df["for_matching"] = df["Airline"]

# clean matching column
df["for_matching"] = clean(df["for_matching"])
df.head()
# Out:
#     Month        Airline   Port_Country  Passengers_In  Freight_In_(tonnes)  \
# 0  Jan-85  Air Caledonie  New Caledonia          725.0                0.368
# 1  Jan-85      Air China          China         1311.0                9.158
# 2  Jan-85      Air India          India         1423.0               44.823
# 3  Jan-85      Air India      Singapore          501.0               10.583
# 4  Jan-85      Air Nauru          Nauru          161.0                0.212
#
#    Mail_In_(tonnes)  Passengers_Out  Freight_Out_(tonnes)  Mail_Out_(tonnes)  \
# 0               0.0           474.0                 0.167                0.0
# 1               0.0          1232.0                 2.587                0.0
# 2               0.0           970.0                 6.708                0.0
# 3               0.0           306.0               124.966                0.0
# 4               0.0            96.0                23.996                0.0
#
#    Year  Month_num for_matching
# 0  1985          1    Caledonie
# 1  1985          1        China
# 2  1985          1        India
# 3  1985          1        India
# 4  1985          1        Nauru

# %% [markdown]
# ##### 2. Apply to airlines dataframe

# %%
# create a new column for matching purposes
df2["for_matching"] = df2["Name"]

# clean matching column
df2["for_matching"] = clean(df2["for_matching"])
df2.head()
# Out:
#    Airline ID                                          Name Alias IATA ICAO  \
# 0          -1                                       Unknown    \N    -  NaN
# 1           1                                Private flight    \N    -  NaN
# 2           2                                   135 Airways    \N  NaN  GNL
# 3           3                                 1Time Airline    \N   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN  WYT
#
#   Callsign         Country Active  \
# 0       \N              \N      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N
#
#                                    for_matching
# 0                                       Unknown
# 1                                Private Flight
# 2                                           135
# 3                                    1Time Line
# 4  2 Sqn No 1 Elementary Flying Training School

# %% [markdown]
# ##### 3. Merge two dataframe

# %%
new_portcountry_df = df.merge(df2, left_on="Airline", right_on="Name",how = "left")

# %%
new_portcountry_df
# Out:
#         Month                Airline   Port_Country  Passengers_In  \
# 0      Jan-85          Air Caledonie  New Caledonia          725.0
# 1      Jan-85              Air China          China         1311.0
# 2      Jan-85              Air India          India         1423.0
# 3      Jan-85              Air India      Singapore          501.0
# 4      Jan-85              Air Nauru          Nauru          161.0
# ...       ...                    ...            ...            ...
# 45407  Nov-21  United Parcel Service          Korea            0.0
# 45408  Nov-21  United Parcel Service      Singapore            0.0
# 45409  Nov-21  United Parcel Service            USA            0.0
# 45410  Nov-21       Vietnam Airlines        Vietnam          360.0
# 45411  Nov-21        Xiamen Airlines          China          206.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0                    0.368             0.000           474.0
# 1                    9.158             0.000          1232.0
# 2                   44.823             0.000           970.0
# 3                   10.583             0.000           306.0
# 4                    0.212             0.000            96.0
# ...                    ...               ...             ...
# 45407                0.000             0.000             0.0
# 45408                0.000             0.000             0.0
# 45409             1622.587             0.000             0.0
# 45410              487.621             1.237           442.0
# 45411              131.500             2.900          1385.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Year  ...  \
# 0                     0.167              0.000  1985  ...
# 1                     2.587              0.000  1985  ...
# 2                     6.708              0.000  1985  ...
# 3                   124.966              0.000  1985  ...
# 4                    23.996              0.000  1985  ...
# ...                     ...                ...   ...  ...
# 45407               614.750              0.000  2021  ...
# 45408               263.367              0.000  2021  ...
# 45409                 0.000              0.000  2021  ...
# 45410               407.243              6.765  2021  ...
# 45411               111.200              0.000  2021  ...
#
#               for_matching_x Airline ID                   Name Alias IATA  \
# 0                  Caledonie        NaN                    NaN   NaN  NaN
# 1                      China      751.0              Air China    \N   CA
# 2                      India        NaN                    NaN   NaN  NaN
# 3                      India        NaN                    NaN   NaN  NaN
# 4                      Nauru        NaN                    NaN   NaN  NaN
# ...                      ...        ...                    ...   ...  ...
# 45407  United Parcel Service     5263.0  United Parcel Service    \N   5X
# 45408  United Parcel Service     5263.0  United Parcel Service    \N   5X
# 45409  United Parcel Service     5263.0  United Parcel Service    \N   5X
# 45410                Vietnam     5309.0       Vietnam Airlines    \N   VN
# 45411                 Xiamen     5484.0        Xiamen Airlines    \N   MF
#
#       ICAO           Callsign        Country Active         for_matching_y
# 0      NaN                NaN            NaN    NaN                    NaN
# 1      CCA          AIR CHINA          China      Y                  China
# 2      NaN                NaN            NaN    NaN                    NaN
# 3      NaN                NaN            NaN    NaN                    NaN
# 4      NaN                NaN            NaN    NaN                    NaN
# ...    ...                ...            ...    ...                    ...
# 45407  UPS                UPS  United States      N  United Parcel Service
# 45408  UPS                UPS  United States      N  United Parcel Service
# 45409  UPS                UPS  United States      N  United Parcel Service
# 45410  HVN  VIET NAM AIRLINES        Vietnam      Y                Vietnam
# 45411  CXA         XIAMEN AIR          China      Y                 Xiamen
#
# [45412 rows x 21 columns]

# %%
new_portcountry_df.loc[new_portcountry_df["for_matching_y"].isnull()].count()
# Out:
# Month                   18595
# Airline                 18595
# Port_Country            18595
# Passengers_In           18583
# Freight_In_(tonnes)     18590
# Mail_In_(tonnes)        18590
# Passengers_Out          18583
# Freight_Out_(tonnes)    18591
# Mail_Out_(tonnes)       18591
# Year                    18595
# Month_num               18595
# for_matching_x          18595
# Airline ID                  0
# Name                        0
# Alias                       0
# IATA                        0
# ICAO                        0
# Callsign                    0
# Country                     0
# Active                      0
# for_matching_y              0
# dtype: int64

# %%
# remove unmatched rows
new_portcountry_df.dropna(new_portcountry_df)
